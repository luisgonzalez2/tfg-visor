# %%
import json 

poblacion_c0 = ["Ajalvir", "Alamo (El)", "Becerril de la Sierra", "Boalo (El)", "Brunete", "Camarma de Esteruelas", "Campo Real", "Cercedilla", "Chinchón", "Cobeña", "Collado Mediano", "Colmenar de Oreja", "Colmenarejo", "Cubas de la Sagra", "Daganzo de Arriba", "Fuente el Saz de Jarama", "Griñón", "Guadalix de la Sierra", "Hoyo de Manzanares", "Loeches", "Manzanares el Real", "Miraflores de la Sierra", "Molar (El)", "Molinos (Los)", "Moraleja de Enmedio", "Morata de Tajuña", "Nuevo Baztán", "Pedrezuela", "Robledo de Chavela", "San Martín de Valdeiglesias", "Serranillos del Valle", "Sevilla la Nueva", "Soto del Real", "Torrejón de Velasco", "Torrejón de la Calzada", "Torrelaguna", "Torres de la Alameda", "Valdetorres de Jarama", "Villa del Prado", "Villarejo de Salvanés"]
poblacion_c1 = ["Arroyomolinos", "Ciempozuelos", "Galapagar", "Mejorada del Campo", "Navalcarnero", "Paracuellos de Jarama", "Torrelodones", "Villanueva de la Cañada", "Villaviciosa de Odón"]
poblacion_c2 = ["Acebeda (La)", "Alameda del Valle", "Aldea del Fresno", "Ambite", "Anchuelo", "Atazar (El)", "Batres", "Belmonte de Tajo", "Berrueco (El)", "Berzosa del Lozoya", "Braojos", "Brea de Tajo", "Buitrago del Lozoya", "Bustarviejo", "Cabanillas de la Sierra", "Cabrera (La)", "Cadalso de los Vidrios", "Canencia", "Carabaña", "Casarrubuelos", "Cenicientos", "Cervera de Buitrago", "Chapinería", "Colmenar del Arroyo", "Corpa", "Estremera", "Fresnedillas de la Oliva", "Fresno de Torote", "Fuentidueña de Tajo", "Garganta de los Montes", "Gargantilla del Lozoya y Pinilla de Buitrago", "Gascones", "Hiruela (La)", "Horcajo de la Sierra-Aoslos", "Horcajuelo de la Sierra", "Lozoya", "Lozoyuela-Navas-Sieteiglesias", "Madarcos", "Montejo de la Sierra", "Navacerrada", "Navalafuente", "Navalagamella", "Navarredonda y San Mamés", "Navas del Rey", "Olmeda de las Fuentes", "Orusco de Tajuña", "Patones", "Pelayos de la Presa", "Perales de Tajuña", "Pezuela de las Torres", "Pinilla del Valle", "Piñuécar-Gandullas", "Pozuelo del Rey", "Prádena del Rincón", "Puebla de la Sierra", "Puentes Viejas", "Quijorna", "Rascafría", "Redueña", "Ribatejada", "Robledillo de la Jara", "Robregordo", "Rozas de Puerto Real", "Santa María de la Alameda", "Santorcaz", "Santos de la Humosa (Los)", "Serna del Monte (La)", "Somosierra", "Talamanca de Jarama", "Tielmes", "Titulcia", "Torremocha de Jarama", "Valdaracete", "Valdeavero", "Valdelaguna", "Valdemanco", "Valdemaqueda", "Valdeolmos-Alalpardo", "Valdepiélagos", "Valdilecha", "Valverde de Alcalá", "Vellón (El)", "Venturada", "Villaconejos", "Villamanrique de Tajo", "Villamanta", "Villamantilla", "Villanueva de Perales", "Villar del Olmo", "Villavieja del Lozoya", "Zarzalejo"]
poblacion_c3 = ["Algete", "Alpedrete", "Escorial (El)", "Guadarrama", "Humanes de Madrid", "Meco", "Moralzarzal", "San Agustín del Guadalix", "San Lorenzo de El Escorial", "San Martín de la Vega", "Valdemorillo", "Velilla de San Antonio", "Villalbilla", "Villanueva del Pardillo"]
densidad_c0 = ["Acebeda (La)", "Alameda del Valle", "Aldea del Fresno", "Ambite", "Anchuelo", "Atazar (El)", "Batres", "Belmonte de Tajo", "Berrueco (El)", "Berzosa del Lozoya", "Braojos", "Brea de Tajo", "Buitrago del Lozoya", "Bustarviejo", "Cabanillas de la Sierra", "Cabrera (La)", "Cadalso de los Vidrios", "Campo Real", "Canencia", "Carabaña", "Cenicientos", "Cervera de Buitrago", "Chapinería", "Chinchón", "Colmenar de Oreja", "Colmenar del Arroyo", "Corpa", "Estremera", "Fresnedillas de la Oliva", "Fresno de Torote", "Fuentidueña de Tajo", "Garganta de los Montes", "Gargantilla del Lozoya y Pinilla de Buitrago", "Gascones", "Guadalix de la Sierra", "Hiruela (La)", "Horcajo de la Sierra-Aoslos", "Horcajuelo de la Sierra", "Lozoya", "Lozoyuela-Navas-Sieteiglesias", "Madarcos", "Manzanares el Real", "Miraflores de la Sierra", "Montejo de la Sierra", "Navacerrada", "Navalafuente", "Navalagamella", "Navarredonda y San Mamés", "Navas del Rey", "Olmeda de las Fuentes", "Orusco de Tajuña", "Patones", "Perales de Tajuña", "Pezuela de las Torres", "Pinilla del Valle", "Piñuécar-Gandullas", "Pozuelo del Rey", "Prádena del Rincón", "Puebla de la Sierra", "Puentes Viejas", "Quijorna", "Rascafría", "Redueña", "Ribatejada", "Robledillo de la Jara", "Robledo de Chavela", "Robregordo", "Rozas de Puerto Real", "San Martín de Valdeiglesias", "Santa María de la Alameda", "Santorcaz", "Santos de la Humosa (Los)", "Serna del Monte (La)", "Somosierra", "Talamanca de Jarama", "Tielmes", "Titulcia", "Torrejón de Velasco", "Torrelaguna", "Torremocha de Jarama", "Valdaracete", "Valdeavero", "Valdelaguna", "Valdemanco", "Valdemaqueda", "Valdemorillo", "Valdepiélagos", "Valdetorres de Jarama", "Valdilecha", "Valverde de Alcalá", "Vellón (El)", "Villa del Prado", "Villaconejos", "Villamanrique de Tajo", "Villamanta", "Villamantilla", "Villanueva de Perales", "Villar del Olmo", "Villarejo de Salvanés", "Villavieja del Lozoya", "Zarzalejo"]
densidad_c1 = ["Alpedrete", "Arroyomolinos", "Humanes de Madrid", "Mejorada del Campo", "Torrejón de la Calzada", "Torrelodones", "Velilla de San Antonio"]
densidad_c2 = ["Alamo (El)", "Algete", "Casarrubuelos", "Ciempozuelos", "Cubas de la Sagra", "Galapagar", "Griñón", "Meco", "Paracuellos de Jarama", "Villalbilla", "Villanueva de la Cañada", "Villanueva del Pardillo", "Villaviciosa de Odón"]
densidad_c3 = ["Ajalvir", "Becerril de la Sierra", "Boalo (El)", "Brunete", "Camarma de Esteruelas", "Cercedilla", "Cobeña", "Collado Mediano", "Colmenarejo", "Daganzo de Arriba", "Escorial (El)", "Fuente el Saz de Jarama", "Guadarrama", "Hoyo de Manzanares", "Loeches", "Molar (El)", "Molinos (Los)", "Moraleja de Enmedio", "Moralzarzal", "Morata de Tajuña", "Navalcarnero", "Nuevo Baztán", "Pedrezuela", "Pelayos de la Presa", "San Agustín del Guadalix", "San Lorenzo de El Escorial", "San Martín de la Vega", "Serranillos del Valle", "Sevilla la Nueva", "Soto del Real", "Torres de la Alameda", "Valdeolmos-Alalpardo", "Venturada"]
distancia_c0 = ["Acebeda (La)", "Alameda del Valle", "Atazar (El)", "Berzosa del Lozoya", "Braojos", "Buitrago del Lozoya", "Cadalso de los Vidrios", "Canencia", "Cenicientos", "Cervera de Buitrago", "Garganta de los Montes", "Gargantilla del Lozoya y Pinilla de Buitrago", "Gascones", "Hiruela (La)", "Horcajo de la Sierra-Aoslos", "Horcajuelo de la Sierra", "Lozoya", "Madarcos", "Montejo de la Sierra", "Navarredonda y San Mamés", "Pinilla del Valle", "Piñuécar-Gandullas", "Prádena del Rincón", "Puebla de la Sierra", "Puentes Viejas", "Rascafría", "Robledillo de la Jara", "Robledo de Chavela", "Robregordo", "Rozas de Puerto Real", "San Martín de Valdeiglesias", "Serna del Monte (La)", "Somosierra", "Valdemaqueda", "Villavieja del Lozoya"]
distancia_c1 = ["Alamo (El)", "Alpedrete", "Anchuelo", "Becerril de la Sierra", "Carabaña", "Chinchón", "Collado Mediano", "Corpa", "Escorial (El)", "Fresno de Torote", "Guadarrama", "Manzanares el Real", "Meco", "Molar (El)", "Moralzarzal", "Navacerrada", "Nuevo Baztán", "Olmeda de las Fuentes", "Pedrezuela", "Pezuela de las Torres", "Pozuelo del Rey", "Quijorna", "Ribatejada", "Santorcaz", "Santos de la Humosa (Los)", "Sevilla la Nueva", "Soto del Real", "Talamanca de Jarama", "Tielmes", "Valdeavero", "Valdelaguna", "Valdemorillo", "Valdepiélagos", "Valdetorres de Jarama", "Valdilecha", "Valverde de Alcalá", "Vellón (El)", "Venturada", "Villamanta", "Villamantilla", "Villanueva de Perales", "Villanueva de la Cañada", "Villar del Olmo", "Villarejo de Salvanés"]
distancia_c2 = ["Aldea del Fresno", "Ambite", "Belmonte de Tajo", "Berrueco (El)", "Boalo (El)", "Brea de Tajo", "Bustarviejo", "Cabanillas de la Sierra", "Cabrera (La)", "Cercedilla", "Chapinería", "Colmenar de Oreja", "Colmenar del Arroyo", "Estremera", "Fresnedillas de la Oliva", "Fuentidueña de Tajo", "Guadalix de la Sierra", "Lozoyuela-Navas-Sieteiglesias", "Miraflores de la Sierra", "Molinos (Los)", "Navalafuente", "Navalagamella", "Navas del Rey", "Orusco de Tajuña", "Patones", "Pelayos de la Presa", "Redueña", "San Lorenzo de El Escorial", "Santa María de la Alameda", "Torrelaguna", "Torremocha de Jarama", "Valdaracete", "Valdemanco", "Villa del Prado", "Villaconejos", "Villamanrique de Tajo", "Zarzalejo"]
distancia_c3 = ["Ajalvir", "Algete", "Arroyomolinos", "Batres", "Brunete", "Camarma de Esteruelas", "Campo Real", "Casarrubuelos", "Ciempozuelos", "Cobeña", "Colmenarejo", "Cubas de la Sagra", "Daganzo de Arriba", "Fuente el Saz de Jarama", "Galapagar", "Griñón", "Hoyo de Manzanares", "Humanes de Madrid", "Loeches", "Mejorada del Campo", "Moraleja de Enmedio", "Morata de Tajuña", "Navalcarnero", "Paracuellos de Jarama", "Perales de Tajuña", "San Agustín del Guadalix", "San Martín de la Vega", "Serranillos del Valle", "Titulcia", "Torrejón de Velasco", "Torrejón de la Calzada", "Torrelodones", "Torres de la Alameda", "Valdeolmos-Alalpardo", "Velilla de San Antonio", "Villalbilla", "Villanueva del Pardillo", "Villaviciosa de Odón"]
zona_este_metropolitano = ['Ajalvir', 'Alcalá de Henares', 'Arganda del Rey', 'Coslada', 'Mejorada del Campo', 'Paracuellos de Jarama', 'Rivas-Vaciamadrid', 'San Fernando de Henares', 'Torrejón de Ardoz', 'Velilla de San Antonio']
zona_municipio_madrid = ['Madrid']
zona_nordeste_comunidad = ['Camarma de Esteruelas', 'Daganzo de Arriba', 'Fresno de Torote', 'Fuente el Saz de Jarama', 'Meco', 'Molar (El)', 'Ribatejada', 'Talamanca de Jarama', 'Valdeavero', 'Valdeolmos-Alalpardo', 'Valdepiélagos', 'Valdetorres de Jarama']
zona_norte_comunidad = ['Alcobendas', 'Algete', 'Cobeña', 'Colmenar Viejo', 'San Agustín del Guadalix', 'San Sebastián de los Reyes', 'Tres Cantos']
zona_oeste_comunidad = ['Boadilla del Monte', 'Brunete', 'Collado Villalba', 'Galapagar', 'Hoyo de Manzanares', 'Majadahonda', 'Pozuelo de Alarcón', 'Rozas de Madrid (Las)', 'Torrelodones', 'Villanueva de la Cañada', 'Villaviciosa de Odón']
zona_sierra_central = ['Alpedrete', 'Becerril de la Sierra', 'Boalo (El)', 'Cercedilla', 'Colmenarejo', 'Collado Mediano', 'Escorial (El)', 'Guadarrama', 'Manzanares el Real', 'Miraflores de la Sierra', 'Molinos (Los)', 'Moralzarzal', 'Navacerrada', 'San Lorenzo de El Escorial', 'Soto del Real', 'Valdemorillo', 'Villanueva del Pardillo']
zona_sierra_norte = ['Acebeda (La)', 'Alameda del Valle', 'Atazar (El)', 'Berzosa del Lozoya', 'Berrueco (El)', 'Braojos', 'Buitrago del Lozoya', 'Bustarviejo', 'Cabanillas de la Sierra', 'Cabrera (La)', 'Canencia', 'Cervera de Buitrago', 'Garganta de los Montes', 'Gargantilla del Lozoya y Pinilla de Buitrago', 'Gascones', 'Guadalix de la Sierra', 'Hiruela (La)', 'Horcajo de la Sierra-Aoslos', 'Horcajuelo de la Sierra', 'Lozoya', 'Madarcos', 'Montejo de la Sierra', 'Navalafuente', 'Navarredonda y San Mamés', 'Patones', 'Pedrezuela', 'Pinilla del Valle', 'Piñuecar-Gandullas', 'Prádena del Rincón', 'Puebla de la Sierra', 'Rascafría', 'Redueña', 'Robledillo de la Jara', 'Robregordo', 'Serna del Monte (La)', 'Somosierra', 'Torrelaguna', 'Torremocha de Jarama', 'Valdemanco', 'Vellón (El)', 'Venturada', 'Villavieja del Lozoya', 'Lozoyuela-Navas-Sieteiglesias', 'Puentes Viejas']
zona_sierra_sur = ['Cadalso de los Vidrios', 'Cenicientos', 'Colmenar del Arroyo', 'Chapinería', 'Fresnedillas de la Oliva', 'Navalagamella', 'Navas del Rey', 'Pelayos de la Presa', 'Robledo de Chavela', 'Rozas de Puerto Real', 'San Martín de Valdeiglesias', 'Santa María de la Alameda', 'Valdemaqueda', 'Zarzalejo']
zona_sudeste_comunidad = ['Ambite', 'Anchuelo', 'Belmonte de Tajo', 'Brea de Tajo', 'Campo Real', 'Carabaña', 'Colmenar de Oreja', 'Corpa', 'Chinchón', 'Estremera', 'Fuentidueña de Tajo', 'Loeches', 'Morata de Tajuña', 'Nuevo Baztán', 'Olmeda de las Fuentes', 'Orusco de Tajuña', 'Perales de Tajuña', 'Pezuela de las Torres', 'Pozuelo del Rey', 'Santorcaz', 'Santos de la Humosa (Los)', 'Tielmes', 'Titulcia', 'Torres de la Alameda', 'Valdaracete', 'Valdelaguna', 'Valdilecha', 'Valverde de Alcalá', 'Villaconejos', 'Villalbilla', 'Villamanrique de Tajo', 'Villar del Olmo', 'Villarejo de Salvanés']
zona_sudoeste_comunidad = ['Alamo (El)', 'Aldea del Fresno', 'Arroyomolinos', 'Batres', 'Casarrubuelos', 'Cubas de la Sagra', 'Griñón', 'Moraleja de Enmedio', 'Navalcarnero', 'Quijorna', 'Serranillos del Valle', 'Sevilla la Nueva', 'Torrejón de la Calzada', 'Torrejón de Velasco', 'Villa del Prado', 'Villamanta', 'Villamantilla', 'Villanueva de Perales']
zona_sur_metropolitano = ['Alcorcón', 'Aranjuez', 'Ciempozuelos', 'Fuenlabrada', 'Getafe', 'Humanes de Madrid', 'Leganés', 'Móstoles', 'Parla', 'Pinto', 'San Martín de la Vega', 'Valdemoro']

# Leer el archivo TXT (GeoJSON) y cargarlo en un objeto Python
txt_file_path = 'municipios-pre.txt'
with open(txt_file_path, 'r', encoding='utf-8') as file:
    geojson = json.load(file)

# Función para crear archivos GeoJSON
def crear_geojson(lista_municipios, nombre_archivo):
    features = [feature for feature in geojson['features'] if feature['properties']['municipio_distrito'] in lista_municipios]
    geojson_nuevo = { "type": "FeatureCollection", "features": features }
    with open(nombre_archivo, 'w', encoding='utf-8') as file:
        json.dump(geojson_nuevo, file, ensure_ascii=False, indent=4)

# Crear archivos GeoJSON para cada lista
crear_geojson(poblacion_c0, 'poblacion_c0.txt')
crear_geojson(poblacion_c1, 'poblacion_c1.txt')
crear_geojson(poblacion_c2, 'poblacion_c2.txt')
crear_geojson(poblacion_c3, 'poblacion_c3.txt')
crear_geojson(densidad_c0, 'densidad_c0.txt')
crear_geojson(densidad_c1, 'densidad_c1.txt')
crear_geojson(densidad_c2, 'densidad_c2.txt')
crear_geojson(densidad_c3, 'densidad_c3.txt')
crear_geojson(distancia_c0, 'distancia_c0.txt')
crear_geojson(distancia_c1, 'distancia_c1.txt')
crear_geojson(distancia_c2, 'distancia_c2.txt')
crear_geojson(distancia_c3, 'distancia_c3.txt')
crear_geojson(zona_este_metropolitano, 'zona_este_metropolitano.txt')
crear_geojson(zona_municipio_madrid, 'zona_municipio_madrid.txt')
crear_geojson(zona_nordeste_comunidad, 'zona_nordeste_comunidad.txt')
crear_geojson(zona_norte_comunidad, 'zona_norte_comunidad.txt')
crear_geojson(zona_oeste_comunidad, 'zona_oeste_comunidad.txt')
crear_geojson(zona_sierra_central, 'zona_sierra_central.txt')
crear_geojson(zona_sierra_norte, 'zona_sierra_norte.txt')
crear_geojson(zona_sierra_sur, 'zona_sierra_sur.txt')
crear_geojson(zona_sudeste_comunidad, 'zona_sudeste_comunidad.txt')
crear_geojson(zona_sudoeste_comunidad, 'zona_sudoeste_comunidad.txt')
crear_geojson(zona_sur_metropolitano, 'zona_sur_metropolitano.txt')
